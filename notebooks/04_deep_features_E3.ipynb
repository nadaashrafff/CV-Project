# %% [markdown]
# # E3 — EfficientNetB0 Deep Features Only
#
# **Owner:** Aly
#
# **Inputs:** `features/deep/train_deep_late.npy`, `val_deep_late.npy`, `test_deep_late.npy` (2048-dim)
#
# **Outputs:**
# - `models/classifiers/svm_E3.pkl`
# - `results/predictions/E3_deep_predictions.csv`
#
# **Classifier:** SVM RBF (`class_weight=balanced`, `probability=True`)
#
# **Dependencies:** Cell 7 (EfficientNetB0 feature extraction)

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0, '/content/drive/MyDrive/CV/repo')
from src.utils.seed import set_seed
set_seed()

# %%
# TODO: load deep features, train SVM, evaluate, save results
