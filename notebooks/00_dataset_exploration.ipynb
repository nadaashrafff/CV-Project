# %% [markdown]
# # 00 — Dataset Exploration
#
# Visual audit of the Garbage Classification dataset before preprocessing.
#
# - Class distribution (images and objects)
# - Sample images per class with bounding boxes
# - Annotation quality checks
# - Resolution and file format summary

# %%
# Setup
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.insert(0, '/content/drive/MyDrive/CV/repo')

from src.utils.seed import set_seed
set_seed()

# %%
# TODO: dataset exploration code
