# %% [markdown]
# # E4–E7 — Early Fusion
#
# **Owner:** Ahmed
#
# **E4:** Raw concatenation (2300-dim) → classifier
# **E5:** PCA reduction → classifier
# **E6:** Autoencoder compression (256-dim) → classifier
# **E7:** Feature selection (top 200) → classifier
#
# **Dependencies:** `features/classical/` + `features/deep/` (Cells 6 & 7)

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0, '/content/drive/MyDrive/CV/repo')
from src.utils.seed import set_seed
set_seed()

# %%
# TODO: Ahmed — implement E4, E5, E6, E7
