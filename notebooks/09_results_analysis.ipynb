# %% [markdown]
# # 09 — Results Analysis & Final Comparison
#
# Aggregates results from all 11 experiments into the final comparison table.
#
# **Inputs:**
# - `results/metrics/detection_results.csv` (E1, E11)
# - `results/metrics/classification_results.csv` (E2–E10)
# - `results/metrics/efficiency_results.csv`
#
# **Outputs:**
# - `results/metrics/final_comparison_table.csv`
# - `figures/final/final_experiment_comparison.png`
# - `figures/final/accuracy_efficiency_tradeoff.png`
# - `figures/compression/accuracy_vs_dimension.png`

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0, '/content/drive/MyDrive/CV/repo')
from src.utils.seed import set_seed
from src.evaluation.plots import plot_accuracy_vs_dimension
set_seed()

# %%
# TODO: load all results CSVs, merge, generate final comparison figures
