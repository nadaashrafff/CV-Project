# %% [markdown]
# # E2 — Classical Features Only
#
# **Owner:** Aly
#
# **Inputs:** `features/classical/train_classical.npy`, `val_classical.npy`, `test_classical.npy`
#
# **Outputs:**
# - `models/classifiers/random_forest_E2.pkl`
# - `results/predictions/E2_classical_predictions.csv`
# - Confusion matrix in `figures/classification/`
#
# **Classifier:** Random Forest (`class_weight=balanced`, seed=42)
#
# **Metric:** Macro-F1 (primary)
#
# **Dependencies:** Cell 6 (classical feature extraction — fix dim mismatch bug first)

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.insert(0, '/content/drive/MyDrive/CV/repo')
from src.utils.seed import set_seed
set_seed()

# %%
# TODO: load features, train RF, evaluate, save results
